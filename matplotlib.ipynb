# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
veri=np.arange(10)

# %%
# %matplotlib notebook 
#grafikler için interaktif pencere eklemek için kullanılır.
#%matplotlib inline
#grafiğin satır içinde statik bir şekilde kullanımını sağlar

# %%
#plt.plot(veri)
plt.title("egri")
plt.xlabel("gibi")
# Out:
# <img src="data:image/png;base64,..." width="640">
# Text(0.5, 0, 'gibi')

# %%
x=[1,2,3,4]
y=[1,4,9,16]
plt.plot(x,y,"ro") #r(red) o nokta şeklinde temsili sağlar 
#^ üçgen şekli
#--tire şekli
#s kare şekli

# %%
d=np.arange(0.,5.,0.2)
plt.plot(d,d,"b--",d,d**2,"bs",d,d**3,"go")
plt.savefig("grafigiml.png")
#grafiği kaydeder 
#dpi çözünürlüğü ayarlar
#bbox_inches="tight"
